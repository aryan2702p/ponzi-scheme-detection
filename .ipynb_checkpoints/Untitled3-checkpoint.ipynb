# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
data = pd.read_csv('Ponzi_contracts.csv')

# %%
label_counts = data['label'].value_counts()
print("Label Distribution:")
print(label_counts)
# Out:
# Label Distribution:
# label
# 0    3586
# 1     200
# Name: count, dtype: int64

# %%
print(data['opcode'].head(1000))
# Out:
# 0      PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 1      PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 2      PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 3      PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 4      PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
#                              ...
# 995    PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 996    PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 997    PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 998    PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# 999    PUSH1 0x60\nPUSH1 0x40\nMSTORE\nCALLDATASIZE\n...
# Name: opcode, Length: 1000, dtype: object

# %%
import re

for index, row in data.iterrows():
    opcode_string = row['opcode']
    opcodes = re.findall(r'\b[A-Z0-9]+(?=\s|$)', opcode_string)
    sorted_opcodes = sorted(set(opcodes))
    opcode_modified = ' '.join(sorted_opcodes)
    data.at[index, 'opcode'] = opcode_modified

# %%
print(data.head())
# Out:
#                                       address  label  \
# 0  0x582b2489710a4189ad558b6958641789587fcc27      1
# 1  0xeb4245c88c660ae4ee23c76954e5490ccd7bbd82      1
# 2  0xd92d62ce8504e5c61aa17d9a9b13c65dbd77c268      1
# 3  0xc352add7ad8cac8baa839d8c88e7e9d7df9a219b      1
# 4  0x3f4dd010fbbc9a9b6d95f1f53837d7e9f3befac8      1
#
#                                               opcode  \
# 0  ADD ADDRESS AND BALANCE CALL CALLDATALOAD CALL...
# 1  ADD ADDRESS AND BALANCE CALL CALLDATALOAD CALL...
# 2  ADD ADDRESS AND BALANCE CALL CALLDATACOPY CALL...
# 3  ADD AND CALL CALLDATALOAD CALLDATASIZE CALLER ...
# 4  ADD ADDRESS AND BALANCE CALL CALLDATACOPY CALL...
#
#                                       creator
# 0  0xc14c291012878568b95cfe3f0973f6d5a3a69b09
# 1  0x43f9179a72d88182891502af8e80c32c7365e62b
# 2  0x288ae6c4fcb11771359f9ee33855043e76c0a8fa
# 3  0xd229dbda0d510d3937604a0edf254004b495a9f0
# 4  0x288ae6c4fcb11771359f9ee33855043e76c0a8fa

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data['opcode'])
X_tokenized = tokenizer.texts_to_sequences(data['opcode'])

max_sequence_length = max(len(seq) for seq in X_tokenized)
X_padded = pad_sequences(X_tokenized, maxlen=max_sequence_length)

# %%
print(X_padded)
# Out:
# [[ 0  0  0 ... 46 52 60]
#  [ 0  0  0 ... 46 52 65]
#  [ 0  0  0 ... 65 69 60]
#  ...
#  [ 0  0  0 ... 46 52 60]
#  [ 0  0  0 ... 46 52 55]
#  [ 0  0  0 ...  8 17 60]]

# %%
# X_train, X_test, y_train, y_test = train_test_split(X_padded, data['label'], test_size=0.2, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_padded, data['label'], test_size=0.2, random_state=42, stratify=data['label'])


X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42, stratify=y_train)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Embedding, Dropout, Flatten
from sklearn.model_selection import train_test_split
import numpy as np

def cnn_lstm_Model():
    model = Sequential([
        Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=max_sequence_length),
        Conv1D(64, 5, activation='relu'),
        MaxPooling1D(pool_size=4),
        LSTM(128),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def mlp_lstm_Model():
    model = Sequential([
        Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=max_sequence_length),
        LSTM(128, return_sequences=True),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def cnn_lstm_dropout_Model():
    model = Sequential([
        Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=max_sequence_length),
        Conv1D(64, 5, activation='relu'),
        MaxPooling1D(pool_size=4),
        LSTM(128),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def cnn_lstm_flatten_Model():
    model = Sequential([
        Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=max_sequence_length),
        Conv1D(64, 5, activation='relu'),
        MaxPooling1D(pool_size=4),
        LSTM(128),
        Flatten(),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def test_model():
    model = Sequential([
        Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=max_sequence_length),
        LSTM(128),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

def plot_confusion_matrix(model, model_name, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_classes = (y_pred > 0.5).astype("int32")

    conf_matrix = confusion_matrix(y_test, y_pred_classes)

    accuracy = accuracy_score(y_test, y_pred_classes)
    precision = precision_score(y_test, y_pred_classes)
    recall = recall_score(y_test, y_pred_classes)
    f1 = f1_score(y_test, y_pred_classes)

    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix - {model_name}\nAccuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-score: {f1:.2f}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

# %%
cnn_lstm_model = cnn_lstm_Model()
cnn_lstm_model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 43/43 [==============================] - 10s 81ms/step - loss: 0.2829 - accuracy: 0.9259 - val_loss: 0.2062 - val_accuracy: 0.9472
# Epoch 2/50
# 43/43 [==============================] - 4s 104ms/step - loss: 0.1995 - accuracy: 0.9472 - val_loss: 0.1864 - val_accuracy: 0.9472
# Epoch 3/50
# 43/43 [==============================] - 3s 74ms/step - loss: 0.1455 - accuracy: 0.9527 - val_loss: 0.1178 - val_accuracy: 0.9670
# Epoch 4/50
# 43/43 [==============================] - 3s 68ms/step - loss: 0.1105 - accuracy: 0.9677 - val_loss: 0.0820 - val_accuracy: 0.9736
# Epoch 5/50
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0956 - accuracy: 0.9703 - val_loss: 0.0804 - val_accuracy: 0.9703
# Epoch 6/50
# 43/43 [==============================] - 4s 91ms/step - loss: 0.0944 - accuracy: 0.9721 - val_loss: 0.1027 - val_accuracy: 0.9637
# Epoch 7/50
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0836 - accuracy: 0.9721 - val_loss: 0.0745 - val_accuracy: 0.9802
# Epoch 8/50
# 43/43 [==============================] - 3s 67ms/step - loss: 0.0775 - accuracy: 0.9750 - val_loss: 0.0718 - val_accuracy: 0.9703
# Epoch 9/50
# 43/43 [==============================] - 3s 65ms/step - loss: 0.0746 - accuracy: 0.9769 - val_loss: 0.0672 - val_accuracy: 0.9868
# Epoch 10/50
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0666 - accuracy: 0.9798 - val_loss: 0.1176 - val_accuracy: 0.9472
# Epoch 11/50
# 43/43 [==============================] - 4s 95ms/step - loss: 0.0777 - accuracy: 0.9747 - val_loss: 0.0591 - val_accuracy: 0.9802
# Epoch 12/50
# 43/43 [==============================] - 3s 65ms/step - loss: 0.0619 - accuracy: 0.9813 - val_loss: 0.0551 - val_accuracy: 0.9868
# Epoch 13/50
# 43/43 [==============================] - 3s 70ms/step - loss: 0.
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0718 - accuracy: 0.9780 - val_loss: 0.0842 - val_accuracy: 0.9637
# Epoch 10/20
# 43/43 [==============================] - 6s 150ms/step - loss: 0.0735 - accuracy: 0.9739 - val_loss: 0.0623 - val_accuracy: 0.9835
# Epoch 11/20
# 43/43 [==============================] - 5s 112ms/step - loss: 0.0572 - accuracy: 0.9824 - val_loss: 0.0661 - val_accuracy: 0.9868
# Epoch 12/20
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0558 - accuracy: 0.9828 - val_loss: 0.0819 - val_accuracy: 0.9637
# Epoch 13/20
# 43/43 [==============================] - 4s 97ms/step - loss: 0.0637 - accuracy: 0.9780 - val_loss: 0.0508 - val_accuracy: 0.9901
# Epoch 14/20
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0575 - accuracy: 0.9813 - val_loss: 0.0860 - val_accuracy: 0.9637
# Epoch 15/20
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0564 - accuracy: 0.9839 - val_loss: 0.0640 - val_accuracy: 0.9802
# Epoch 16/20
# 43/43 [==============================] - 4s 97ms/step - loss: 0.0461 - accuracy: 0.9850 - val_loss: 0.0501 - val_accuracy: 0.9868
# Epoch 17/20
# 43/43 [==============================] - 4s 101ms/step - loss: 0.0439 - accuracy: 0.9846 - val_loss: 0.0458 - val_accuracy: 0.9868
# Epoch 18/20
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0447 - accuracy: 0.9850 - val_loss: 0.0463 - val_accuracy: 0.9901
# Epoch 19/20
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0450 - accuracy: 0.9831 - val_loss: 0.0481 - val_accuracy: 0.9901
# Epoch 20/20
# 43/43 [==============================] - 4s 86ms/step - loss: 0.0393 - accuracy: 0.9875 - val_loss: 0.0589 - val_accuracy: 0.9835

# %%
plot_confusion_matrix(cnn_lstm_model, "CNN-LSTM", X_test, y_test)
plot_confusion_matrix(mlp_lstm_model, "MLP_LSTM", X_test, y_test)
plot_confusion_matrix(cnn_lstm_dropout_model, "CNN_LSTM_DROP", X_test, y_test)
plot_confusion_matrix(cnn_lstm_flatten_model, "CNN_LSTM_FLAT", X_test, y_test)
# Out:
# 24/24 [==============================] - 2s 21ms/step
# 24/24 [==============================] - 3s 86ms/step
# 24/24 [==============================] - 2s 37ms/step
# 24/24 [==============================] - 1s 29ms/step

# %%
cnn_lstm_model.save("cnn_lstm_model.h5")

mlp_lstm_model.save("mlp_lstm_model.h5")

cnn_lstm_dropout_model.save("cnn_lstm_dropout_model.h5")

cnn_lstm_flatten_model.save("cnn_lstm_flatten_model.h5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-42ab179890f0> in <cell line: 2>()
#       1 # Save CNN with LSTM model
# ----> 2 cnn_lstm_model.save("cnn_lstm_model.h5")
#       3
#       4 # Save MLP with LSTM model
#       5 mlp_lstm_model.save("mlp_lstm_model.h5")
#
# AttributeError: 'function' object has no attribute 'save'

# %%
test_model1=test_model()
test_model1.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
#